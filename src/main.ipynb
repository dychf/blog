# %%
import os
import sys
import yaml
from invest.stock import Stock
import pandas as pd
import logging

os.chdir(sys.path[0])

logger = logging.getLogger(__name__)

with open("config.yaml", "r", encoding="utf-8") as file:
    config = yaml.safe_load(file)

columns = ["name", "price", "V", "sell", "buy", "pe_avg", "period"]
data = []
for s_info in config["stock_codes"]:
    try:
        stock_info = Stock(s_info["code"]).valuation()
        data.append(
            [
                stock_info.name,
                stock_info.market_price,
                stock_info.valuation_price,
                stock_info.ideal_sell,
                stock_info.ideal_buy,
                stock_info.industry_mean_pe,
                stock_info.period,
            ]
        )

    except Exception as e:
        logger.error(f"An error occurred: {e}")
        continue
df = pd.DataFrame(data, columns=columns)
df
# Out:
# An error occurred: could not convert string to float: '--'
#    name   price       V    sell     buy  pe_avg                    period
# 0  美的集团   68.58  125.23   75.14   62.61    21.4  [2021FY, 2022FY, 2023FY]
# 1  格力电器   40.61   96.02   57.61   48.01    21.4  [2020FY, 2021FY, 2022FY]
# 2  洋河股份   95.75   77.75   46.65   38.87     9.2  [2021FY, 2022FY, 2023FY]
# 3  小熊电器   56.48   80.53   48.32   40.27    22.9  [2021FY, 2022FY, 2023FY]
# 4   五粮液  155.02   98.30   58.98   49.15     9.2  [2021FY, 2022FY, 2023FY]
# 5   片仔癀  236.31  136.46   81.87   68.23    20.0  [2021FY, 2022FY, 2023FY]
# 6  安井食品   92.39 -639.28 -958.92 -319.64   -59.0  [2021FY, 2022FY, 2023FY]
# 7  小商品城    8.82  101.68   61.01   50.84    54.0  [2021FY, 2022FY, 2023FY]
# 8  江中药业   26.45   31.52   18.91   15.76    20.0  [2021FY, 2022FY, 2023FY]
